# %% [markdown]
# ### Evalution of Machine Learning Algorithms for IDS
#
# In this project, the different machine learning algorihtms are tested for predicting the cyber attacks. At end, the algorithms are compared and suggest the best one. The cyber attacks used  in this dataset are listed in the below section- 1.Data and its overiew.

# %% [markdown]
# ### Table of Contents
# <a>1. Data </a><br>
#    &nbsp; &nbsp; <a>1.1 Data Overview</a>
#
# <a>2.Data pre-processing</a><br>
#   &nbsp; &nbsp; <a> 2.1 Missing Values</a><br>
#   &nbsp; &nbsp; <a> 2.2 Duplicate Values</a><br>
#   &nbsp; &nbsp; <a> 2.3 Categorize numeric features</a><br>
#   &nbsp; &nbsp; <a>2.4 Standardizing numeric features</a><br>
#   &nbsp; &nbsp; <a>2.5 Imbalanced Data</a><br>
#
# <a>3. Feature Selection</a><br>
#    &nbsp; &nbsp; <a>3.1 Chi-square test of Independence </a><br>
#    &nbsp; &nbsp; <a>3.2 Kruskal-Wallis H-test</a><br>
#    &nbsp; &nbsp; <a>3.3 Correlation Matrix</a><br>
#    &nbsp; &nbsp; <a>3.3.1 Significance of the correlation coefficient</a><br>
#    &nbsp; &nbsp; <a>3.4 Conclusion of Independent Tests</a><br>
#
#
# <a>4. Model Building</a><br>
#    &nbsp; &nbsp; <a>4.1 Baseline Model</a><br>
#    &nbsp; &nbsp; <a>4.1.1 Hyperparameters tuning</a><br>
#    &nbsp; &nbsp; <a>4.2.2 Threshold tuning</a><br>
#    &nbsp; &nbsp; <a>4.2.3 Evaluation</a><br>
#
#    &nbsp; &nbsp; <a>4.2 Logistic Regression</a><br>
#    &nbsp; &nbsp; <a>4.2.1 Hyperparameters tuning</a><br>
#    &nbsp; &nbsp; <a>4.2.2 Threshold tuning</a><br>
#    &nbsp; &nbsp; <a>4.2.3 Evaluation</a><br>
#
#    &nbsp; &nbsp; <a>4.3 Decision Tree</a><br>
#    &nbsp; &nbsp; <a>4.3.1 Hyperparameters tuning</a><br>
#    &nbsp; &nbsp; <a>4.3.2 Threshold tuning</a><br>
#    &nbsp; &nbsp; <a>4.3.3 Evaluation</a><br>
#
#    &nbsp; &nbsp; <a>4.4 Random Forests Classifier</a><br>
#    &nbsp; &nbsp; <a>4.4.1 Hyperparameters tuning</a><br>
#    &nbsp; &nbsp; <a>4.4.2 Threshold tuning</a><br>
#    &nbsp; &nbsp; <a>4.4.3 Evaluation</a><br>
#
#    &nbsp; &nbsp; <a>4.5 Support Vector Machine</a><br>
#    &nbsp; &nbsp; <a>4.5.1 Hyperparameters tuning</a><br>
#    &nbsp; &nbsp; <a>4.5.2 Threshold tuning</a><br>
#    &nbsp; &nbsp; <a>4.5.3 Evaluation</a><br>
#
#    &nbsp; &nbsp; <a>4.6 XGBoost Classifier</a><br>
#    &nbsp; &nbsp; <a>4.6.1 Hyperparameters tuning</a><br>
#    &nbsp; &nbsp; <a>4.6.2 Threshold tuning</a><br>
#    &nbsp; &nbsp; <a>4.6.3 Evaluation</a><br>
#
#    &nbsp; &nbsp; <a>4.7 KNN Classifierv</a><br>
#    &nbsp; &nbsp; <a>4.7.1 Hyperparameters tuning</a><br>
#    &nbsp; &nbsp; <a>4.7.2 Threshold tuning</a><br>
#    &nbsp; &nbsp; <a>4.7.3 Evaluation</a><br>
#
#    &nbsp; &nbsp; <a>4.8 Gaussian Naive Bayes</a><br>
#    &nbsp; &nbsp; <a>4.8.1 Hyperparameters tuning</a><br>
#    &nbsp; &nbsp; <a>4.8.2 Threshold tuning</a><br>
#    &nbsp; &nbsp; <a>4.8.3 Evaluation</a><br>
#
#    &nbsp; &nbsp; <a>4.9 GradienBoost Classifier</a><br>
#    &nbsp; &nbsp; <a>4.9.1 Hyperparameters tuning</a><br>
#    &nbsp; &nbsp; <a>4.9.2 Threshold tuning</a><br>
#    &nbsp; &nbsp; <a>4.9.3 Evaluation</a><br>
#
#    &nbsp; &nbsp; <a>4.10 XBoost Classifier</a><br>
#    &nbsp; &nbsp; <a>4.10.1 Hyperparameters tuning</a><br>
#    &nbsp; &nbsp; <a>4.10.2 Threshold tuning</a><br>
#    &nbsp; &nbsp; <a>4.10.3 Evaluation</a><br>
#
#    &nbsp; &nbsp; <a>4.11 XLight GBM Classifierr</a><br>
#    &nbsp; &nbsp; <a>4.11.1 Hyperparameters tuning</a><br>
#    &nbsp; &nbsp; <a>4.11.2 Threshold tuning</a><br>
#    &nbsp; &nbsp; <a>4.11.3 Evaluation</a><br>
#
#
# <a>5. Conclusion</a>
#
#
# <a>In progress ..... </a>

# %%
# import necessary dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Data

# %%
# define function to load dataset
def load_data(data, feat_name):
    df= pd.read_csv(data, names=feat_name)
    return df

# %%
# call function
feature_names = ['duration','protocol-type', 'service','flag','src_bytes', 'dst_bytes', 'Land', 'wrong_fragment', 'urgent',
                 'hot', 'num_failed_logins','login','num_compromised','root-shell', 'su_attempted', 'num_root', 'num_file_creattin',
                'num_shells', 'num_access_files','num_outbound_cmds','is_hot_login','is_guest_login','count','srv_count','serror_rate',
                'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
                'dst_host_srv_count', 'dst_host_same_srv_rate', 'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate', 'dst_host_srv_dff_host_rate',
                'dst_host_serror_rate', 'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate', 'attack-type','dificul_level']
test_data= load_data('NSL-KDD/KDDTest+.txt', feature_names)
train_data = load_data('NSL-KDD/KDDTrain+.txt', feature_names)
train_data.head()
# Out:
#    duration protocol-type   service flag  src_bytes  dst_bytes  Land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# 1                    0.60                         0.88
# 2                    0.05                         0.00
# 3                    0.00                         0.03
# 4                    0.00                         0.00
#
#    dst_host_srv_dff_host_rate  dst_host_serror_rate  dst_host_srv_serror_rate  \
# 0                        0.00                  0.00                      0.00
# 1                        0.00                  0.00                      0.00
# 2                        0.00                  1.00                      1.00
# 3                        0.04                  0.03                      0.01
# 4                        0.00                  0.00                      0.00
#
#    dst_host_rerror_rate  dst_host_srv_rerror_rate  attack-type  dificul_level
# 0                  0.05                      0.00       normal             20
# 1                  0.00                      0.00       normal             15
# 2                  0.00                      0.00      neptune             19
# 3                  0.00                      0.01       normal             21
# 4                  0.00                      0.00       normal             21
#
# [5 rows x 43 columns]

# %%
#show list of attack-type
test_data['attack-type'].value_counts()
# Out:
# normal             9711
# neptune            4657
# guess_passwd       1231
# mscan               996
# warezmaster         944
# apache2             737
# satan               735
# processtable        685
# smurf               665
# back                359
# snmpguess           331
# saint               319
# mailbomb            293
# snmpgetattack       178
# portsweep           157
# ipsweep             141
# httptunnel          133
# nmap                 73
# pod                  41
# buffer_overflow      20
# multihop             18
# named                17
# ps                   15
# sendmail             14
# xterm                13
# rootkit              13
# teardrop             12
# xlock                 9
# land                  7
# xsnoop                4
# ftp_write             3
# perl                  2
# phf                   2
# udpstorm              2
# sqlattack             2
# loadmodule            2
# worm                  2
# imap                  1
# Name: attack-type, dtype: int64

# %% [markdown]
# #### Categories attacks
#
# All  attacks are categorized into 4 different attacks i.e 1)  Probe, 2) DoS(Denial of Service), 3) User to Root (U2R) and 4) Remote to Local(R2L).

# %%
# attacks in 4 category
Probe= ['ipsweep', 'nmap','portsweep', 'satan','saint','mscan']
DoS = ['back', 'land','neptune','pod','smurf', 'teardrop','apache2','udpstorm','processtable','mailbomb' ]
U2R =['buffer_overflow','loadmodule','perl','rootkit','spy','xterm','ps','httptunnel','sqlattack','worm','snmpguess']
R2L =['ftp_write','guess_passwd','imap','multihop','phf','warezclient','warezmaster','snmpgetattack','named','xlock','xsnoop','sendmail']

# make 4 generic attack types in both train and test data
for x in [train_data, test_data]:
    for att_type in zip([Probe, DoS, U2R, R2L],['Probe', 'DoS', 'U2R', 'R2L']):
        x['attack-type']= x['attack-type'].replace(att_type[0], att_type[1])


        
        
print('Few sample of train data:')
test_data.head()
# Out:
# Few sample of train data:
#    duration protocol-type   service  flag  src_bytes  dst_bytes  Land  \
# 0         0           tcp   private   REJ          0          0     0
# 1         0           tcp   private   REJ          0          0     0
# 2         2           tcp  ftp_data    SF      12983          0     0
# 3         0          icmp     eco_i    SF         20          0     0
# 4         1           tcp    telnet  RSTO          0         15     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.04
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.61
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    0.31
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.06                         0.00
# 1                    0.06                         0.00
# 2                    0.04                         0.61
# 3                    0.00                         1.00
# 4                    0.17                         0.03
#
#    dst_host_srv_dff_host_rate  dst_host_serror_rate  dst_host_srv_serror_rate  \
# 0                        0.00                   0.0                       0.0
# 1                        0.00                   0.0                       0.0
# 2                        0.02                   0.0                       0.0
# 3                        0.28                   0.0                       0.0
# 4                        0.02                   0.0                       0.0
#
#    dst_host_rerror_rate  dst_host_srv_rerror_rate  attack-type  dificul_level
# 0                  1.00                      1.00          DoS             21
# 1                  1.00                      1.00          DoS             21
# 2                  0.00                      0.00       normal             21
# 3                  0.00                      0.00        Probe             15
# 4                  0.83                      0.71        Probe             11
#
# [5 rows x 43 columns]

# %% [markdown]
# #### 1.1 Data Overview

# %%
print('No. of rows in Test data:', test_data.shape[0])
print('No. of columns in Test data:', test_data.shape[1])
print('No. of rows in Test data:', train_data.shape[0])
print('No. of columns in Test data:', train_data.shape[1])
print('\nNull values in test data: \n', test_data.isnull().sum())
print('\nNull values in train data: \n', train_data.isnull().sum())
# Out:
# No. of rows in Test data: 22544
# No. of columns in Test data: 43
# No. of rows in Test data: 125973
# No. of columns in Test data: 43
#
# Null values in test data:
#  duration                       0
# protocol-type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# Land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# login                          0
# num_compromised                0
# root-shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creattin              0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_hot_login                   0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# same_srv_rate                  0
# diff_srv_rate                  0
# srv_diff_host_rate             0
# dst_host_count                 0
# dst_host_srv_count             0
# dst_host_same_srv_rate         0
# dst_host_diff_srv_rate         0
# dst_host_same_src_port_rate    0
# dst_host_srv_dff_host_rate     0
# dst_host_serror_rate           0
# dst_host_srv_serror_rate       0
# dst_host_rerror_rate           0
# dst_host_srv_rerror_rate       0
# attack-type                    0
# dificul_level                  0
# dtype: int64
#
# Null values in train data:
#  duration                       0
# protocol-type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# Land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# login                          0
# num_compromised                0
# root-shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creattin              0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_hot_login                   0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# same_srv_rate                  0
# diff_srv_rate                  0
# srv_diff_host_rate             0
# dst_host_count                 0
# dst_host_srv_count             0
# dst_host_same_srv_rate         0
# dst_host_diff_srv_rate         0
# dst_host_same_src_port_rate    0
# dst_host_srv_dff_host_rate     0
# dst_host_serror_rate           0
# dst_host_srv_serror_rate       0
# dst_host_rerror_rate           0
# dst_host_srv_rerror_rate       0
# attack-type                    0
# dificul_level                  0
# dtype: int64

# %% [markdown]
# #### Observation:
# No null values are found in both train and test data.

# %% [markdown]
# ### 2. Data Wrangling

# %% [markdown]
# #### 2.1 Missing Values

# %%
test_data=test_data.dropna()

# %%
test_data.shape
# Out:
# (22544, 43)

# %% [markdown]
# ####  2.2 Duplicate Values

# %%
#check duplicates and drop them
test_data=test_data.drop_duplicates()
train_data=train_data.drop_duplicates()

print('Rows after removing duplicates in test data',test_data.shape)
print('Rows after removing duplicates in train data',train_data.shape)
# Out:
# Rows after removing duplicates in test data (22541, 43)
# Rows after removing duplicates in train data (125964, 43)

# %% [markdown]
# #### 2.3 Categorize numeric features
# There are three features which are categorical (protocol-type,service and flag). We use one-hot-encoding to convert into numerical

# %%
#test_data.dtypes gives us protocol_type, service and flags as categorical varibales
print('Protocol types:',test_data['protocol-type'].unique(),'\n')
print('Service types:',test_data['service'].unique(),'\n')
print('Flag types:',test_data['flag'].unique())
# Out:
# Protocol types: ['tcp' 'icmp' 'udp']
#
# Service types: ['private' 'ftp_data' 'eco_i' 'telnet' 'http' 'smtp' 'ftp' 'ldap' 'pop_3'
#  'courier' 'discard' 'ecr_i' 'imap4' 'domain_u' 'mtp' 'systat' 'iso_tsap'
#  'other' 'csnet_ns' 'finger' 'uucp' 'whois' 'netbios_ns' 'link' 'Z39_50'
#  'sunrpc' 'auth' 'netbios_dgm' 'uucp_path' 'vmnet' 'domain' 'name' 'pop_2'
#  'http_443' 'urp_i' 'login' 'gopher' 'exec' 'time' 'remote_job' 'ssh'
#  'kshell' 'sql_net' 'shell' 'hostnames' 'echo' 'daytime' 'pm_dump' 'IRC'
#  'netstat' 'ctf' 'nntp' 'netbios_ssn' 'tim_i' 'supdup' 'bgp' 'nnsp' 'rje'
#  'printer' 'efs' 'X11' 'ntp_u' 'klogin' 'tftp_u']
#
# Flag types: ['REJ' 'SF' 'RSTO' 'S0' 'RSTR' 'SH' 'S3' 'S2' 'S1' 'RSTOS0' 'OTH']

# %% [markdown]
# #### Plotting the protocol types as a pie chart

# %%
#show protocol types in dataset
for data in zip([test_data, train_data], ['Test-Data', 'Train-Data']):
    labels = list(data[0]['protocol-type'].value_counts().index)
    sizes = list(data[0]['protocol-type'].value_counts().values)
    explode = (0, 0, 0.2)  # only "explode" 3rd slice (i.e. 'udp')

    fig1, ax1 = plt.subplots(figsize=(7,5))
    ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=180)

    ax1.axis('equal')  
    ax1.set_title('\n\n Protocol-Type in '+ data[1]+':\n')
    plt.legend(loc=1)

    plt.show()

# %% [markdown]
# #### Note:
# Three type of network protocols i.e 1) UDP,  2)ICMP  and  3)TCP are seen in the dataset. Above pie-charts show the
# volumn distribution of protocol in both test and train data.

# %% [markdown]
# #### Plotting the attack-types  as a pie chart

# %%
# show attack types in dataset
for data in zip([test_data, train_data], ['Test-Data', 'Train-Data']):
    labels = list(data[0]['attack-type'].value_counts().index)
    sizes = list(data[0]['attack-type'].value_counts().values)
    explode = (0, 0,0,0,0.3)  # only "explode" 5th slice 

    fig1, ax1 = plt.subplots(figsize=(7,5))
    ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',shadow=True, startangle=180)

    ax1.axis('equal')  
    ax1.set_title('\n\n Attack-Type in '+ data[1]+':\n')
    plt.legend(loc=2)

    plt.show()
